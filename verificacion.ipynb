# %%
from pathlib import Path

PROJECT_DIR = Path.cwd()

required_dirs = [
    PROJECT_DIR / "data" / "source" / "nih",
    PROJECT_DIR / "data" / "working" / "nih" / "meta",
    PROJECT_DIR / "data" / "working" / "nih" / "active_subset",
    PROJECT_DIR / "data" / "manifests",
]

for d in required_dirs:
    d.mkdir(parents=True, exist_ok=True)

print("Estructura creada/verificada:\n")
for d in required_dirs:
    print("-", d)
# Out:
# Estructura creada/verificada:
#
# - /mnt/d/Universidad/analitica/proyecto_analitica2/data/source/nih
# - /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/meta
# - /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/active_subset
# - /mnt/d/Universidad/analitica/proyecto_analitica2/data/manifests

# %%
from pathlib import Path

archive_path = Path("data/source/nih/archive.zip")

print("Ruta esperada:", archive_path.resolve())
print("¿Existe archive.zip?:", archive_path.exists())
# Out:
# Ruta esperada: /mnt/d/Universidad/analitica/proyecto_analitica2/data/source/nih/archive.zip
# ¿Existe archive.zip?: True

# %%
from pathlib import Path

print("Directorio actual del notebook:")
print(Path.cwd())

meta_dir = Path("data/working/nih/meta")
print("\nRuta absoluta de meta_dir:")
print(meta_dir.resolve())
print("\n¿Existe meta_dir?:", meta_dir.exists())

if meta_dir.exists():
    print("\nContenido completo dentro de meta_dir:")
    for p in meta_dir.rglob("*"):
        print("-", p)
# Out:
# Directorio actual del notebook:
# /mnt/d/Universidad/analitica/proyecto_analitica2
#
# Ruta absoluta de meta_dir:
# /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/meta
#
# ¿Existe meta_dir?: True
#
# Contenido completo dentro de meta_dir:
# - data/working/nih/meta/Data_Entry_2017.csv
# - data/working/nih/meta/test_list.txt
# - data/working/nih/meta/train_val_list.txt

# %%
from pathlib import Path

meta_dir = Path("data/working/nih/meta")

print("Chequeo exacto de nombres:\n")
for name in ["Data_Entry_2017.csv", "train_val_list.txt", "test_list.txt"]:
    p = meta_dir / name
    print(name, "->", p.exists(), "| ruta:", p.resolve())
# Out:
# Chequeo exacto de nombres:
#
# Data_Entry_2017.csv -> True | ruta: /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/meta/Data_Entry_2017.csv
# train_val_list.txt -> True | ruta: /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/meta/train_val_list.txt
# test_list.txt -> True | ruta: /mnt/d/Universidad/analitica/proyecto_analitica2/data/working/nih/meta/test_list.txt

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"

meta_dir = DATA_DIR / "working" / "nih" / "meta"
manifests_dir = DATA_DIR / "manifests"
manifests_dir.mkdir(parents=True, exist_ok=True)

metadata_csv = meta_dir / "Data_Entry_2017.csv"
test_file = meta_dir / "test_list.txt"
train_val_file = meta_dir / "train_val_list.txt"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("meta_dir:", meta_dir)
print("metadata_csv:", metadata_csv)
print("test_file:", test_file)
print("train_val_file:", train_val_file)
# Out:
# PROJECT_ROOT: /mnt/d/Universidad/analitica
# meta_dir: /mnt/d/Universidad/analitica/data/working/nih/meta
# metadata_csv: /mnt/d/Universidad/analitica/data/working/nih/meta/Data_Entry_2017.csv
# test_file: /mnt/d/Universidad/analitica/data/working/nih/meta/test_list.txt
# train_val_file: /mnt/d/Universidad/analitica/data/working/nih/meta/train_val_list.txt

# %%
from pathlib import Path

if Path.cwd().name == "notebooks":
    PROJECT_ROOT = Path.cwd().parent
else:
    PROJECT_ROOT = Path.cwd()

DATA_DIR = PROJECT_ROOT / "data"
SOURCE_DIR = DATA_DIR / "source"
WORKING_DIR = DATA_DIR / "working"
MANIFESTS_DIR = DATA_DIR / "manifests"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
print("WORKING_DIR:", WORKING_DIR)
print("MANIFESTS_DIR:", MANIFESTS_DIR)
# Out:
# PROJECT_ROOT: /mnt/d/Universidad/analitica/proyecto_analitica2
# DATA_DIR: /mnt/d/Universidad/analitica/proyecto_analitica2/data
# WORKING_DIR: /mnt/d/Universidad/analitica/proyecto_analitica2/data/working
# MANIFESTS_DIR: /mnt/d/Universidad/analitica/proyecto_analitica2/data/manifests
